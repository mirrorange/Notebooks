# %%
# 下载代码和模型
# %tensorflow_version 1.x
# !git clone https://github.com/openai/gpt-2/
# %cd gpt-2
# !python download_model.py 1558M
# !pip3 install -r requirements.txt

# %%
# 开始生成文本
# %cd gpt-2
# !python3 src/interactive_conditional_samples.py --top_k 40 --model_name 1558M
